# %%
# only need to run these commands if using Colab
# Mount google drive and change directory to the git repo folder
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/CITS4012_2023
import sys
# colab seems to require an explicit path for this to work from mounted drive
sys.path.append('/content/gdrive/MyDrive/CITS4012_2023/src/QA')
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/CITS4012_2023

# %%
# %cd models
# Out:
# /content/gdrive/MyDrive/CITS4012_2023/models

# %%
# %ls
# Out:
# Assi_figure1.PNG         initial_results_exploration.ipynb  test_cut.tsv
# assignment_overview.png  models/                            train_cut.tsv
# assign_report.docx       NDCbefaftresults.pkl               WikiQA-test.tsv
# code.ipynb               README.md                          WikiQA-train.tsv
# environment.yml          src/

# %%
import pickle

# %%
with open('results.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
# %cd /content/gdrive/MyDrive/CITS4012_2023/
with open('GRUbefaftresults.pkl', 'rb') as f:
    BAresults = pickle.load(f)
resultkeys = BAresults.keys()
ResultsDict = {}
mod_num = 0
for i in resultkeys:
    mod_num += 1
    mod_dict = {}
    for j in i:
        mod_dict[j[0]] = j[1]
    for k in BAresults[i]:
        for l in ['precision', 'recall', 'f1-score', 'support']:
            mod_dict[f'{k} {l}'] = BAresults[i][k]['test_report']['1'][l]
            mod_dict[f'{k} training {l}'] = BAresults[i][k]['train_report']['1'][l]
    ResultsDict[f'Model {mod_num}'] = mod_dict
resDFBA = pd.DataFrame(ResultsDict) # convert into pandas dataframe
BAresDFT = resDFBA.transpose()
# Out:
# /content/gdrive/MyDrive/CITS4012_2023

# %%
len(BAresDFT)
# Out:
# 121

# %%
import math
try:
    notnanlist = []
    for i in BAresDFT["40 f1-score"]:
        notnanlist.append(math.isnan(i) == False)
    print(f'Max f1 for 40 iters {max(BAresDFT[notnanlist]["40 f1-score"])}')
except:
    pass
print(f'Max f1 for 20 iters {max(BAresDFT["20 f1-score"])}')
print(f'Max f1 for 10 iters {max(BAresDFT["10 f1-score"])}')
print(f'Max f1 for 5 iters {max(BAresDFT["5 f1-score"])}')
print(f'Max f1 for 1 iters {max(BAresDFT["1 f1-score"])}')
# Out:
# Max f1 for 40 iters 0.19573907513400565
# Max f1 for 20 iters 0.17055255230470848
# Max f1 for 10 iters 0.16147699090658582
# Max f1 for 5 iters 0.16567333445937793
# Max f1 for 1 iters 0.13422568093385215

# %%
resultkeys = results.keys()

# %%
ResultsDict = {}
mod_num = 0
for i in resultkeys:
    mod_num += 1
    mod_dict = {}
    for j in i:
        mod_dict[j[0]] = j[1]
    for k in [1,5,10,20]:
        for l in ['precision', 'recall', 'f1-score', 'support']:
            mod_dict[f'{k} {l}'] = results[i][k]['test_report']['1'][l]
            mod_dict[f'{k} training {l}'] = results[i][k]['train_report']['1'][l]
    ResultsDict[f'Model {mod_num}'] = mod_dict

# %%
import pandas as pd

# %%
resDF = pd.DataFrame(ResultsDict) # convert into pandas dataframe

# %%
resDFT_full = resDF.transpose()

# %%
resDFT = resDFT_full[resDFT_full['hidden_type'] == 'RNN'] # Just look at the RNN models

# %%
resDFT.keys()
# Out:
# Index(['befaft', 'doc_with_wm', 'q_cut_size', 'bidirectional', 'learning_rate',
#        'q_with_pos', 'doc_with_ner', 'answer_type', 'batch', 'hidden_size',
#        'attention_type', 'q_with_ner', 'doc_cut_size', 'hidden_type',
#        'doc_hidden_layers', 'doc_with_tfidf', 'iters_inc', 'doc_with_pos',
#        '1 precision', '1 training precision', '1 recall', '1 training recall',
#        '1 f1-score', '1 training f1-score', '1 support', '1 training support',
#        '5 precision', '5 training precision', '5 recall', '5 training recall',
#        '5 f1-score', '5 training f1-score', '5 support', '5 training support',
#        '10 precision', '10 training precision', '10 recall',
#        '10 training recall', '10 f1-score', '10 training f1-score',
#        '10 support', '10 training support', '20 precision',
#        '20 training precision', '20 recall', '20 training recall',
#        '20 f1-score', '20 training f1-score', '20 support',
#        '20 training support'],
# ...

# %%
print(f'Max f1 for 20 iters {max(resDFT["20 f1-score"])}')
print(f'Max f1 for 10 iters {max(resDFT["10 f1-score"])}')
print(f'Max f1 for 5 iters {max(resDFT["5 f1-score"])}')
print(f'Max f1 for 1 iters {max(resDFT["1 f1-score"])}')
# Out:
# Max f1 for 20 iters 0.18330762913854226
# Max f1 for 10 iters 0.17609118935583318
# Max f1 for 5 iters 0.16743569480204962
# Max f1 for 1 iters 0.14067188757959453

# %% [markdown]
# # Best for 20 iterations

# %%
best20iter = resDFT[max(resDFT['20 f1-score'])-0.005 <= resDFT['20 f1-score']]
best20iter = best20iter.sort_values(by='20 f1-score', ascending = False)

# %%
best20iter[['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'answer_type', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#            doc_with_wm      attention_type q_with_ner doc_with_ner  \
# Model 390        False         Dot Product       True         True
# Model 1337        True  Scaled Dot Product       True         True
# Model 1578       False              Cosine       True        False
# Model 1840        True              Cosine      False        False
# Model 1678        True              Cosine      False         True
# Model 559        False         Dot Product      False         True
# Model 520         True         Dot Product      False         True
# Model 1677        True  Scaled Dot Product      False         True
#
#            hidden_size hidden_type doc_hidden_layers doc_with_pos  \
# Model 390          100         RNN                 1        False
# Model 1337         100         RNN                 1        False
# Model 1578         100         RNN                 1        False
# Model 1840         100         RNN                 1        False
# ...

# %%
best20iter[['1 f1-score','5 f1-score','10 f1-score','20 f1-score']]
# Out:
#            1 f1-score 5 f1-score 10 f1-score 20 f1-score
# Model 390    0.093239   0.133971    0.137956    0.183308
# Model 1337   0.098549   0.133706     0.15013    0.182845
# Model 1578    0.10513    0.13903     0.16457    0.181578
# Model 1840   0.006645   0.137846    0.138446    0.179816
# Model 1678   0.099692   0.135458    0.154261    0.179754
# Model 559    0.046109   0.154098    0.137565     0.17956
# Model 520    0.101345   0.155622    0.141697    0.178517
# Model 1677   0.101888   0.134619    0.138747    0.178484

# %%
best20iter[['20 precision','20 recall','20 f1-score','20 support']]
# Out:
#            20 precision 20 recall 20 f1-score 20 support
# Model 390      0.545346  0.110169    0.183308      41536
# Model 1337     0.494101  0.112178    0.182845      36959
# Model 1578     0.623764  0.106255    0.181578      49259
# Model 1840     0.695626  0.103253    0.179816      56531
# Model 1678     0.679418  0.103579    0.179754      55040
# Model 559      0.582291  0.106146     0.17956      46031
# Model 520      0.447027  0.111527    0.178517      33633
# Model 1677     0.602074  0.104772    0.178484      48219

# %% [markdown]
# # BefAft

# %%
BAbest20iter = BAresDFT[max(BAresDFT['20 f1-score'])-0.01 <= BAresDFT['20 f1-score']]
BAbest20iter = BAbest20iter.sort_values(by='20 f1-score', ascending = False)

# %%
BAbest20iter[['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#           doc_with_wm attention_type q_with_ner doc_with_ner hidden_size  \
# Model 591        True         Cosine       True        False         100
# Model 475       False    Dot Product      False         True         100
# Model 510        True         Cosine       True        False         100
# Model 430        True    Dot Product      False         True         100
#
#           hidden_type doc_hidden_layers doc_with_pos learning_rate q_with_pos  \
# Model 591         RNN                 1        False           0.1       True
# Model 475         RNN                 1        False           0.1      False
# Model 510         RNN                 1        False           0.1      False
# Model 430         RNN                 1        False           0.1      False
#
#           befaft q_cut_size doc_with_tfidf doc_cut_size bidirectional
# Model 591   True        Max          False          256          True
# ...

# %%
BAbest40iter = BAresDFT[notnanlist]
BAbest40iter = BAbest40iter[max(BAbest40iter['40 f1-score'])-0.02 <= BAbest40iter['40 f1-score']]
BAbest40iter = BAbest40iter.sort_values(by='40 f1-score', ascending = False)

# %%
BAbest40iter[['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#          doc_with_wm attention_type q_with_ner doc_with_ner hidden_size  \
# Model 13       False    Dot Product       True        False         100
# Model 9        False    Dot Product       True        False         100
# Model 14       False    Dot Product       True        False         100
# Model 16       False    Dot Product       True        False         100
#
#          hidden_type doc_hidden_layers doc_with_pos learning_rate q_with_pos  \
# Model 13         GRU                 1        False           0.1      False
# Model 9          GRU                 1        False           0.1      False
# Model 14         GRU                 2        False           0.1      False
# Model 16         GRU                 4        False           0.1      False
#
#          befaft q_cut_size doc_with_tfidf doc_cut_size bidirectional
# Model 13   True        Max           True          256          True
# Model 9    True        Max           True          256         False
# ...

# %%
BAbest40iter[['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#           doc_with_wm attention_type q_with_ner doc_with_ner hidden_size  \
# Model 59         True         Cosine       True         True         100
# Model 107       False    Dot Product      False         True         100
# Model 100       False    Dot Product      False         True         100
# Model 60         True    Dot Product       True         True         100
#
#           hidden_type doc_hidden_layers doc_with_pos learning_rate q_with_pos  \
# Model 59          GRU                 4         True          0.01       True
# Model 107         GRU                 4        False           0.1      False
# Model 100         GRU                 1        False           0.1      False
# Model 60          GRU                 1         True           0.1       True
#
#           befaft q_cut_size doc_with_tfidf doc_cut_size bidirectional
# Model 59    True        Max           True          256          True
# ...

# %%
BAbest40iter[['1 f1-score','5 f1-score','10 f1-score','20 f1-score', '40 f1-score', '40 training f1-score']]
# Out:
#          1 f1-score 5 f1-score 10 f1-score 20 f1-score 40 f1-score  \
# Model 13    0.04982   0.117923    0.135007    0.169817    0.183261
# Model 9    0.075721    0.10959    0.139312    0.140924    0.182148
# Model 14   0.000476   0.137518    0.146291      0.1677    0.176183
# Model 16   0.098232   0.110895    0.145641    0.166801    0.164322
#
#          40 training f1-score
# Model 13              0.22421
# Model 9              0.247659
# Model 14             0.233844
# Model 16             0.208993

# %%
BAbest40iter[['1 f1-score','5 f1-score','10 f1-score','20 f1-score', '40 f1-score', '40 training f1-score']]
# Out:
#           1 f1-score 5 f1-score 10 f1-score 20 f1-score 40 f1-score  \
# Model 59    0.086759   0.134448    0.141101    0.151821    0.195739
# Model 107    0.10019   0.135391    0.149732    0.197972    0.189989
# Model 100   0.048023   0.087284    0.135166    0.163587    0.188672
# Model 60    0.073987   0.136455    0.145085     0.13959    0.175905
#
#           40 training f1-score
# Model 59              0.192733
# Model 107             0.281517
# Model 100             0.216115
# Model 60              0.195342

# %%
BAbest20iter[['1 f1-score','5 f1-score','10 f1-score','20 f1-score', '20 training f1-score']]
# Out:
#          1 f1-score 5 f1-score 10 f1-score 20 f1-score 20 training f1-score
# Model 13    0.04982   0.117923    0.135007    0.169817             0.196239
# Model 14   0.000476   0.137518    0.146291      0.1677             0.185917
# Model 16   0.098232   0.110895    0.145641    0.166801             0.176179

# %%
BAbest20iter[['20 precision','20 recall','20 f1-score','20 support']]
# Out:
#           20 precision 20 recall 20 f1-score 20 support
# Model 591     0.468955    0.1231     0.19501      31966
# Model 475     0.449529  0.122758    0.192852      30727
# Model 510     0.594089    0.1131    0.190024      44076
# Model 430     0.551305  0.113185    0.187812      40871

# %%
BAdoc_wm_abl = BAresDFT[(BAresDFT['doc_with_wm']==False) & (BAresDFT['attention_type']=='Dot Product') & (BAresDFT['q_with_ner']==True) & (BAresDFT['doc_with_ner']==True) & (BAresDFT['doc_with_pos']==False) & (BAresDFT['q_with_pos']==False) & (BAresDFT['doc_with_tfidf']==True) & (BAresDFT['learning_rate']==0.1)][['doc_with_wm','bidirectional','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
BAdoc_wm_abl
# Out:
#           doc_with_wm bidirectional 10 precision 10 recall 10 f1-score  \
# Model 463       False          True     0.903587  0.076533    0.141114
# Model 466       False         False     0.811226  0.076166    0.139258
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 463             0.152799      0.89012  0.078577    0.144407
# Model 466             0.151554     0.915028  0.075763     0.13994
#
#           20 training f1-score 20 support
# Model 463             0.162623      95053
# Model 466             0.153407     101342

# %% [markdown]
# # 20 iteration feature ablation

# %%
doc_wm_abl = resDFT[(resDFT['attention_type']=='Dot Product') & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)][['doc_with_wm','bidirectional','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_wm_abl
# Out:
#           doc_with_wm bidirectional 10 precision 10 recall 10 f1-score  \
# Model 390       False         False     0.923132  0.074548    0.137956
# Model 350        True         False     0.885949  0.073439    0.135635
# Model 389       False          True     0.860803  0.082007    0.149748
# Model 349        True          True      0.98701  0.072456    0.135001
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 390             0.150327     0.545346  0.110169    0.183308
# Model 350             0.150101     0.506614  0.105746    0.174971
# Model 389             0.161373     0.860922  0.083593    0.152389
# Model 349             0.144099      0.84388  0.082398    0.150136
#
#           20 training f1-score 20 support
# Model 390             0.201254      41536
# Model 350             0.205566      40200
# Model 389              0.16957      86419
# Model 349             0.170998      85937

# %%
doc_ner_abl = resDFT[(resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1) & (resDFT['bidirectional']==False)][['q_with_ner','doc_with_ner','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_ner_abl
# Out:
#           q_with_ner doc_with_ner 10 precision 10 recall 10 f1-score  \
# Model 390       True         True     0.923132  0.074548    0.137956
# Model 470       True        False     0.972351  0.072305    0.134601
# Model 400      False         True     0.624121  0.095057    0.164986
# Model 480      False        False     0.970206   0.07303    0.135836
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 390             0.150327     0.545346  0.110169    0.183308
# Model 470             0.142528     0.748063  0.087495    0.156667
# Model 400             0.176073     0.824812  0.083964    0.152413
# Model 480             0.143424     0.990943  0.072925    0.135852
#
#           20 training f1-score 20 support
# Model 390             0.201254      41536
# Model 470             0.172006      71741
# Model 400             0.172298      82428
# Model 480             0.143376     114022

# %%
doc_pos_abl = resDFT[(resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['doc_with_pos','q_with_pos','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_pos_abl
# Out:
#           doc_with_pos q_with_pos 10 precision 10 recall 10 f1-score  \
# Model 390        False      False     0.923132  0.074548    0.137956
# Model 70          True      False     0.826957  0.086663    0.156884
# Model 370        False       True     0.987367  0.072317    0.134764
# Model 50          True       True     0.991419  0.072621     0.13533
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 390             0.150327     0.545346  0.110169    0.183308
# Model 70              0.165358     0.682755  0.092517    0.162952
# Model 370              0.14294     0.636754   0.08776    0.154259
# Model 50              0.143553     0.919318   0.07537    0.139319
#
#           20 training f1-score 20 support
# Model 390             0.201254      41536
# Model 70              0.188806      61924
# Model 370             0.174667      60882
# Model 50              0.149454     102348

# %%
# get f1 scores for the different permutations of NER and POS
dpY_qpY_dnY_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpY_qpY_dnN_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpN_dnY_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpN_dnN_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]

dpY_qpN_dnY_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpY_qpN_dnN_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpY_dnY_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpY_dnN_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]


dpY_qpY_dnY_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpY_qpY_dnN_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpN_dnY_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpN_dnN_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]

dpY_qpN_dnY_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpY_qpN_dnN_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==True) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpY_dnY_qnN = resDFT[(resDFT['q_with_ner']==False) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]
dpN_qpY_dnN_qnY = resDFT[(resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==False) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==True) & (resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)& (resDFT['bidirectional']==False)][['20 f1-score']]['20 f1-score'][0]

# %%
pos_ner_table = pd.DataFrame([[dpN_qpN_dnN_qnN, dpY_qpN_dnN_qnN, dpN_qpY_dnN_qnN, dpY_qpY_dnN_qnN],[dpN_qpN_dnY_qnN, dpY_qpN_dnY_qnN, dpN_qpY_dnY_qnN, dpY_qpY_dnY_qnN],[dpN_qpN_dnN_qnY, dpY_qpN_dnN_qnY, dpN_qpY_dnN_qnY, dpY_qpY_dnN_qnY],[dpN_qpN_dnY_qnY, dpY_qpN_dnY_qnY, dpN_qpY_dnY_qnY, dpY_qpY_dnY_qnY]], columns=['No POS', 'Doc POS', 'Q POS', 'Doc and Q POS'], index=['No NER', 'Doc NER', 'Q NER','Doc and Q NER'])
pos_ner_table
# Out:
#                  No POS   Doc POS     Q POS  Doc and Q POS
# No NER         0.135852  0.136478  0.136189       0.135272
# Doc NER        0.152413  0.162322  0.157546       0.148523
# Q NER          0.156667  0.168905  0.134523       0.145634
# Doc and Q NER  0.183308  0.162952  0.154259       0.139319

# %%
doc_tfidf_abl = resDFT[(resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['learning_rate']==0.1)][['doc_with_tfidf','bidirectional','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_tfidf_abl
# Out:
#           doc_with_tfidf bidirectional 10 precision 10 recall 10 f1-score  \
# Model 390           True         False     0.923132  0.074548    0.137956
# Model 550          False         False     0.910499  0.075789    0.139931
# Model 389           True          True     0.860803  0.082007    0.149748
# Model 549          False          True     0.270766  0.120091    0.166386
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 390             0.150327     0.545346  0.110169    0.183308
# Model 550             0.149986     0.691217  0.092075    0.162504
# Model 389             0.161373     0.860922  0.083593    0.152389
# Model 549             0.172213     0.885711  0.079867    0.146521
#
#           20 training f1-score 20 support
# Model 390             0.201254      41536
# Model 550             0.172628      62992
# Model 389              0.16957      86419
# Model 549             0.164244      93055

# %%
doc_wm_abl = resDFT[(resDFT['doc_with_wm']==False) & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_tfidf']==True) & (resDFT['learning_rate']==0.1)][['attention_type','bidirectional','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_wm_abl
# Out:
#                 attention_type bidirectional 10 precision 10 recall  \
# Model 390          Dot Product         False     0.923132  0.074548
# Model 1418              Cosine          True     0.599928  0.096537
# Model 1419  Scaled Dot Product         False     0.820284    0.0793
# Model 389          Dot Product          True     0.860803  0.082007
# Model 1420              Cosine         False     0.417114  0.101688
# Model 1417  Scaled Dot Product          True     0.995591  0.072795
#
#            10 f1-score 10 training f1-score 20 precision 20 recall  \
# Model 390     0.137956             0.150327     0.545346  0.110169
# Model 1418    0.166312              0.17869      0.80491  0.085813
# Model 1419    0.144619             0.155205     0.770826  0.084582
# Model 389     0.149748             0.161373     0.860922  0.083593
# Model 1420    0.163513             0.169938     0.952092  0.076439
# Model 1417     0.13567              0.14334      0.06066  0.109627
#
# ...

# %%
doc_wm_abl = resDFT[(resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False) & (resDFT['doc_with_tfidf']==True)][['learning_rate','bidirectional','10 precision','10 recall','10 f1-score','10 training f1-score','20 precision','20 recall','20 f1-score','20 training f1-score','20 support']].sort_values(by='20 f1-score', ascending=False)
doc_wm_abl
# Out:
#           learning_rate bidirectional 10 precision 10 recall 10 f1-score  \
# Model 390           0.1         False     0.923132  0.074548    0.137956
# Model 389           0.1          True     0.860803  0.082007    0.149748
# Model 388          0.01         False     0.798475  0.057789    0.107777
# Model 387          0.01          True     0.290788  0.059212    0.098389
# Model 385         0.001          True     0.615898  0.057736    0.105575
# Model 384        0.0001         False     0.988082  0.051738    0.098327
# Model 381       0.00001          True      0.49994  0.053878    0.097273
# Model 383        0.0001          True     0.846979  0.051039    0.096276
# Model 386         0.001         False     0.240972  0.056659    0.091746
# Model 382       0.00001         False     0.817304  0.049743    0.093778
#
#           10 training f1-score 20 precision 20 recall 20 f1-score  \
# Model 390             0.150327     0.545346  0.110169    0.183308
# ...

# %%
from results_helpers import ResultsHelper

# %%
# %matplotlib inline

# %%
import matplotlib as plt

# %%
ResultsHelper.plot_metrics_over_its('q_with_pos')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-050b82565fc3> in <cell line: 1>()
# ----> 1 ResultsHelper.plot_metrics_over_its('q_with_pos')
#
# /content/gdrive/MyDrive/CITS4012_2023/src/QA/model/results_helpers.py in plot_metrics_over_its(param, train)
#      80
#      81         # should only be 1 value
# ---> 82         for value in param.values():
#      83             for it in value.keys():
#      84                 its.append(it)
#
# AttributeError: 'str' object has no attribute 'values'

# %% [markdown]
# # Best for 10 iterations

# %%
resDFT[max(resDFT['10 f1-score'])-0.015 <= resDFT['10 f1-score']][['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'answer_type', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#           doc_with_wm      attention_type q_with_ner doc_with_ner hidden_size  \
# Model 58         True              Cosine       True         True         100
# Model 79         True  Scaled Dot Product      False         True         100
# Model 297       False  Scaled Dot Product       True        False         100
# Model 397        True  Scaled Dot Product      False         True         100
#
#           hidden_type doc_hidden_layers doc_with_pos learning_rate  \
# Model 58          RNN                 1         True           0.1
# Model 79          RNN                 1         True           0.1
# Model 297         RNN                 1         True           0.1
# Model 397         RNN                 1         True           0.1
#
#           answer_type q_with_pos befaft q_cut_size doc_with_tfidf  \
# Model 58   Out_And_In      False  False        Max           True
# Model 79   Out_And_In      False  False        Max           True
# ...

# %%
resDFT[max(resDFT['10 f1-score'])-0.01 <= resDFT['10 f1-score']][['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'answer_type', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#            doc_with_wm      attention_type q_with_ner doc_with_ner  \
# Model 510         True         Dot Product       True         True
# Model 519         True         Dot Product      False         True
# Model 549        False         Dot Product       True         True
# Model 698         True              Cosine       True         True
# Model 937        False  Scaled Dot Product       True        False
# Model 1418       False              Cosine       True         True
#
#            hidden_size hidden_type doc_hidden_layers doc_with_pos  \
# Model 510          100         RNN                 1        False
# Model 519          100         RNN                 1        False
# Model 549          100         RNN                 1        False
# Model 698          100         RNN                 1         True
# Model 937          100         RNN                 1         True
# Model 1418         100         RNN                 1        False
#
# ...

# %%
resDFT[max(resDFT['10 f1-score'])-0.015 <= resDFT['10 f1-score']][['1 f1-score','5 f1-score','10 f1-score','20 f1-score']]
# Out:
#           1 f1-score 5 f1-score 10 f1-score 20 f1-score
# Model 58     0.08388   0.134181     0.16787    0.144918
# Model 79    0.077138   0.134911    0.165732    0.156528
# Model 297   0.096972   0.139786    0.176091    0.154424
# Model 397   0.097706   0.135415    0.164624     0.15397

# %%
resDFT[max(resDFT['10 f1-score'])-0.01 <= resDFT['10 f1-score']][['1 f1-score','5 f1-score','10 f1-score','20 f1-score']]
# Out:
#            1 f1-score 5 f1-score 10 f1-score 20 f1-score
# Model 510    0.096531     0.1477    0.171847    0.153633
# Model 519    0.098874   0.135533    0.174021    0.166251
# Model 549    0.097586   0.134819    0.166386    0.146521
# Model 698     0.08388   0.134181     0.16787    0.144918
# Model 937    0.096972   0.139786    0.176091    0.154424
# Model 1418   0.096965    0.13864    0.166312    0.155091

# %%
resDFT[max(resDFT['10 f1-score'])-0.015 <= resDFT['10 f1-score']][['10 precision','10 recall','10 f1-score','10 support']]
# Out:
#           10 precision 10 recall 10 f1-score 10 support
# Model 58      0.443332  0.103538     0.16787      35929
# Model 79      0.551067  0.097532    0.165732      47410
# Model 297      0.51734  0.106103    0.176091      40913
# Model 397     0.677035  0.093704    0.164624      60627

# %% [markdown]
# # Best for 5 iterations

# %%
resDFT[(resDFT['doc_with_wm']==False) & (resDFT['attention_type']=='Dot Product') & (resDFT['q_with_ner']==True) & (resDFT['doc_with_ner']==True) & (resDFT['doc_with_pos']==False) & (resDFT['q_with_pos']==False)][['learning_rate', '20 f1-score']]

# %%
resDFT[max(resDFT['5 f1-score'])-0.015 <= resDFT['5 f1-score']][['doc_with_wm', 'attention_type', 'q_with_ner', 'doc_with_ner', 'hidden_size', 'hidden_type', 'doc_hidden_layers', 'doc_with_pos', 'learning_rate', 'answer_type', 'q_with_pos', 'befaft', 'q_cut_size', 'doc_with_tfidf', 'doc_cut_size', 'bidirectional']]
# Out:
#            doc_with_wm      attention_type q_with_ner doc_with_ner  \
# Model 79         False         Dot Product      False         True
# Model 138        False         Dot Product      False        False
# Model 240        False         Dot Product      False         True
# Model 520         True         Dot Product      False         True
# Model 559        False         Dot Product      False         True
# Model 1097       False  Scaled Dot Product       True         True
# Model 1198        True              Cosine      False        False
#
#            hidden_size hidden_type doc_hidden_layers doc_with_pos  \
# Model 79           100         RNN                 1         True
# Model 138          100         RNN                 1         True
# Model 240          100         RNN                 1         True
# Model 520          100         RNN                 1        False
# Model 559          100         RNN                 1        False
# ...

# %%
resDFT[max(resDFT['5 f1-score'])-0.015 <= resDFT['5 f1-score']][['1 f1-score','5 f1-score','10 f1-score','20 f1-score']]
# Out:
#            1 f1-score 5 f1-score 10 f1-score 20 f1-score
# Model 79      0.10441    0.15824    0.165989    0.159281
# Model 138    0.074541   0.152633    0.134696    0.133985
# Model 240    0.095955    0.15628    0.136364       0.172
# Model 520    0.101345   0.155622    0.141697    0.178517
# Model 559    0.046109   0.154098    0.137565     0.17956
# Model 1097   0.098197   0.167436     0.14981    0.151948
# Model 1198    0.10844   0.154166    0.141077    0.065173

# %%
resDFT[max(resDFT['5 f1-score'])-0.015 <= resDFT['5 f1-score']][['5 precision','5 recall','5 f1-score','5 support']]
# Out:
#           5 precision  5 recall 5 f1-score 5 support
# Model 457    0.391372  0.106499   0.167436     30836
# Model 558    0.692885  0.086732   0.154166     67034

# %% [markdown]
# # 1 Iteration

# %%
resDFT[max(resDFT['1 f1-score'])-0.01 <= resDFT['1 f1-score']][['learning_rate','1 f1-score','5 f1-score','10 f1-score','20 f1-score']].sort_values(by='1 f1-score', ascending = False)
# Out:
#            learning_rate 1 f1-score 5 f1-score 10 f1-score 20 f1-score
# Model 498           0.01   0.140672   0.136641    0.135944    0.136779
# Model 1782       0.00001    0.14064   0.140751    0.140699    0.140987
# Model 90             0.1   0.138285   0.134637    0.134648    0.136173
# Model 1139           0.1   0.138039   0.134959    0.136204    0.137753
# Model 1078           0.1   0.137371   0.135138    0.135293    0.135312
# Model 125          0.001   0.136525   0.139763    0.137946    0.137345
# Model 202        0.00001   0.136316    0.13633    0.136225    0.136294
# Model 44          0.0001   0.136168   0.135751    0.135298    0.135992
# Model 379            0.1   0.135713   0.135216    0.136475    0.147577
# Model 1477           0.1   0.135455   0.135274    0.136087    0.150257
# Model 318           0.01    0.13478   0.142224    0.141231    0.136046
# Model 58            0.01   0.134121   0.135276    0.134917    0.135202
# ...
